# %%
#Faça um programa, com uma função que necessite de três argumentos, e que forneça a soma desses três argumentos.

def soma(num1,num2,num3):

    return num1 + num2 + num3
    
num1 = int(input("Informe um numero: "))
num2 = int(input("Informe um numero: "))
num3 = int(input("Informe um numero: "))
resultado = soma(num1,num2,num3)
print(resultado)
# Out:
# Informe um numero: 5
# Informe um numero: 4
# Informe um numero: 3
# 12

# %%
#Faça um programa, com uma função que necessite de um argumento. A função retorna o valor de caractere ‘P’, se seu argumento for positivo, e ‘N’, se seu argumento for zero ou negativo.

def verificar(valor):
    if valor > 0:
        return "Positivo"
    if valor == 0:
        return "Nulo"
    if valor < 0:
        return "Negativo"
    
valor = int(input("Informe o valor: "))
print(verificar(valor))
# Out:
# Informe o valor: 0
# Nulo

# %%
#Faça um programa com uma função chamada somaImposto. A função possui dois parâmetros formais: taxaImposto, que é a quantia de imposto sobre vendas expressa em porcentagem e custo, que é o custo de um item antes do imposto. A função “altera” o valor de custo para incluir o imposto sobre vendas.
def somaImposto(taxa,custo):
    return ((taxa / 100)*custo) + custo
    
taxa = float(input("Informe a taxa: "))
custo = float(input("Informe o custo: "))
resultado = somaImposto(taxa,custo)
print("CUSTO FINAL:{}".format(resultado))
# Out:
# Informe a taxa: 15
# Informe o custo: 500
# CUSTO FINAL:575.0

# %%
#Faça um programa que converta da notação de 24 horas para a notação de 12 horas. Por exemplo, o programa deve converter 14:25 em 2:25 P.M. A entrada é dada em dois inteiros. Deve haver pelo menos duas funções: uma para fazer a conversão e uma para a saída. Registre a informação A.M./P.M. como um valor ‘A’ para A.M. e ‘P’ para P.M. Assim, a função para efetuar as conversões terá um parâmetro formal para registrar se é A.M. ou P.M. Inclua um loop que permita que o usuário repita esse cálculo para novos valores de entrada todas as vezes que desejar.
def conversao(numero,minutos):
    if numero == 12:
        caracter = "PM"
    elif numero > 12:
        caracter = "PM"
        numero = numero - 12
        if numero == 12:
            caracter = "AM"
    
    else:
        caracter = "AM"
    return numero,minutos,caracter


continuar = True
while continuar:
    hora = int(input("Informe uma hora: "))
    minutos = int(input("Informe os minutos: "))
    resultado_hora = conversao(hora,minutos)
    print("%s:%s %s"%resultado_hora)
    opcao = input("Deseja continuar? ")
    if opcao == "N" or opcao == "n":
        break

# %%
'''
PROJETO ESTACIONAMENTO
'''
import matplotlib.pyplot as plt

from random import shuffle

listaVagasLivres = ["A1", "A2", "A3", "A4", "A5", "B1", "B2", "B3", "B4", "C1", "C2", "C3",  "C4", "D1", "D2", "D3", "D4"]
listaVagasOcupadas = []
continuar = 'S'
i = 1
j = 1

while continuar == 'S':

       quantidade = int(input('\nDigite quantos Carros estão entrando no estacionamento: '))

             if quantidade > len(listaVagasLivres):
                print('''\nA Quantidade de carro é maior que a quantidade de vagas.

                Temos {} Vagas'''.format(len(listaVagasLivres)))

             else:
                for x in range(quantidade):
                    shuffle(listaVagasLivres)
                    listaVagasOcupadas.append(listaVagasLivres.pop())

                    print('\nCarro {} na vaga {}'.format(i,listaVagasOcupadas[x]))
                    print('\nVAGAS LIVRES:', listaVagasLivres)
                    print('VAGAS OCUPADAS:', listaVagasOcupadas)
                    i += 1

                saida = int(input("\nQuantos carros sairam? "))
      

             for x in range(saida):
         
                listaVagasLivres.append(listaVagasOcupadas.pop(0))
                print('\nVAGAS LIVRES:', listaVagasLivres)
                print('VAGAS OCUPADAS:', listaVagasOcupadas)
                print('\nCarro {} saiu na vaga {}'.format(j,listaVagasLivres[len(listaVagasLivres) -1]))
        
                j += 1
        
                continuar = input('\nDeseja continuar (S | N): ')
plt.plot(listaVagasLivres)
# Out:
#   File "<ipython-input-32-a0feb90e28d9>", line 18
#     if quantidade > len(listaVagasLivres):
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt

listaVagasLivres = ["A1", "A2", "A3", "A4", "A5", "B1", "B2", "B3", "B4", "C1", "C2", "C3",  "C4", "D1", "D2", "D3", "D4"]
listaVagasOcupadas = ["A6"]

plt.plot(listaVagasLivres),([1,2,3,4])
plt.ylabel('some numbers')

plt.show()

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
# Importing the dataset
data = pd.read_csv('atletas.csv')
print(data.shape)
data.head()
f1 = data['height'].values
f2 = data['weight'].values
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)
# Out:
# (11538, 11)

# %% [markdown]
# <i> TRAVEI AQUI,como remover o NaN????

# %%
soma = 0
for x in range(len(lista_altura)):
    if lista_altura[x] != "nan":
        soma = soma + lista_altura[x]
print(soma / len(lista_altura))
